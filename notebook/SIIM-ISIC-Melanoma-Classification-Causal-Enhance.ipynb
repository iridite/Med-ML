# %%
# !git clone https://github.com/haqishen/SIIM-ISIC-Melanoma-Classification-1st-Place-Solution.git repo
# Out:
# fatal: destination path 'repo' already exists and is not an empty directory.
# repo  state.db

# %%
# !ls repo
import sys
sys.path.append('./repo')
# Out:
# dataset.py   evaluate.py  LICENSE    predict.py  requirements.txt  util.py
# ensemble.py  figure1.png  models.py  README.md	 train.py

# %%
import os

# 假设原代码里有一个常量定义文件
import repo.models as models 

# 动态修改路径配置，使其指向 Kaggle 的数据集路径
DATA_PATH = '/kaggle/input/siim-isic-melanoma-classification'
# 如果代码中有 config 对象，直接赋值覆盖
# config.train_path = os.path.join(DATA_PATH, 'jpeg/train')
